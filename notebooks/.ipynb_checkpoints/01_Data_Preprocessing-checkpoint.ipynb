# %% [markdown]
# # Data preprocessing

# %% [markdown]
# ## Navigation
# <ul>
# <li><a href="#transformation">Data Transformation</a></li>
# <li><a href="#outliers">Outliers exploration and handling</a></li>
# <li><a href="#Feature Engineering">Feature Engineering</a></li>
#     </ul>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import datetime as dt
# %matplotlib inline

# %%
# csv
df = pd.read_csv("../data/raw/train.csv")

# %%
df.shape
# Out:
# (233154, 41)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 233154 entries, 0 to 233153
# Data columns (total 41 columns):
#  #   Column                               Non-Null Count   Dtype
# ---  ------                               --------------   -----
#  0   UNIQUEID                             233154 non-null  int64
#  1   DISBURSED_AMOUNT                     233154 non-null  int64
#  2   ASSET_COST                           233154 non-null  int64
#  3   LTV                                  233154 non-null  float64
#  4   BRANCH_ID                            233154 non-null  int64
#  5   SUPPLIER_ID                          233154 non-null  int64
#  6   MANUFACTURER_ID                      233154 non-null  int64
#  7   CURRENT_PINCODE_ID                   233154 non-null  int64
#  8   DATE_OF_BIRTH                        233154 non-null  object
#  9   EMPLOYMENT_TYPE                      225493 non-null  object
#  10  DISBURSAL_DATE                       233154 non-null  object
#  11  STATE_ID                             233154 non-null  int64
#  12  EMPLOYEE_CODE_ID                     233154 non-null  int64
#  13  MOBILENO_AVL_FLAG                    233154 non-null  int64
#  14  AADHAR_FLAG                          233154 non-null  int64
#  15  PAN_FLAG                             233154 non-null  int64
#  16  VOTERID_FLAG                         233154 non-null  int64
#  17  DRIVING_FLAG                         233154 non-null  int64
#  18  PASSPORT_FLAG                        233154 non-null  int64
#  19  PERFORM_CNS_SCORE                    233154 non-null  int64
#  20  PERFORM_CNS_SCORE_DESCRIPTION        233154 non-null  object
#  21  PRI_NO_OF_ACCTS                      233154 non-null  int64
#  22  PRI_ACTIVE_ACCTS                     233154 non-null  int64
#  23  PRI_OVERDUE_ACCTS                    233154 non-null  int64
#  24  PRI_CURRENT_BALANCE                  233154 non-null  int64
#  25  PRI_SANCTIONED_AMOUNT                233154 non-null  int64
#  26  PRI_DISBURSED_AMOUNT                 233154 non-null  int64
#  27  SEC_NO_OF_ACCTS                      233154 non-null  int64
#  28  SEC_ACTIVE_ACCTS                     233154 non-null  int64
#  29  SEC_OVERDUE_ACCTS                    233154 non-null  int64
#  30  SEC_CURRENT_BALANCE                  233154 non-null  int64
#  31  SEC_SANCTIONED_AMOUNT                233154 non-null  int64
#  32  SEC_DISBURSED_AMOUNT                 233154 non-null  int64
#  33  PRIMARY_INSTAL_AMT                   233154 non-null  int64
#  34  SEC_INSTAL_AMT                       233154 non-null  int64
#  35  NEW_ACCTS_IN_LAST_SIX_MONTHS         233154 non-null  int64
#  36  DELINQUENT_ACCTS_IN_LAST_SIX_MONTHS  233154 non-null  int64
#  37  AVERAGE_ACCT_AGE                     233154 non-null  object
#  38  CREDIT_HISTORY_LENGTH                233154 non-null  object
#  39  NO_OF_INQUIRIES                      233154 non-null  int64
#  40  LOAN_DEFAULT                         233154 non-null  int64
# dtypes: float64(1), int64(34), object(6)
# memory usage: 72.9+ MB

# %%
df.describe()
# Out:
#             UNIQUEID  DISBURSED_AMOUNT    ASSET_COST            LTV  \
# count  233154.000000     233154.000000  2.331540e+05  233154.000000
# mean   535917.573376      54356.993528  7.586507e+04      74.746530
# std     68315.693711      12971.314171  1.894478e+04      11.456636
# min    417428.000000      13320.000000  3.700000e+04      10.030000
# 25%    476786.250000      47145.000000  6.571700e+04      68.880000
# 50%    535978.500000      53803.000000  7.094600e+04      76.800000
# 75%    595039.750000      60413.000000  7.920175e+04      83.670000
# max    671084.000000     990572.000000  1.628992e+06      95.000000
#
#            BRANCH_ID    SUPPLIER_ID  MANUFACTURER_ID  CURRENT_PINCODE_ID  \
# count  233154.000000  233154.000000    233154.000000       233154.000000
# mean       72.936094   19638.635035        69.028054         3396.880247
# std        69.834995    3491.949566        22.141304         2238.147502
# min         1.000000   10524.000000        45.000000            1.000000
# 25%        14.000000   16535.000000        48.000000         1511.000000
# 50%        61.000000   20333.000000        86.000000         2970.000000
# 75%       130.000000   23000.000000        86.000000         5677.000000
# max       261.000000   24803.000000       156.000000         7345.000000
#
#             STATE_ID  EMPLOYEE_CODE_ID  ...  SEC_OVERDUE_ACCTS  \
# count  233154.000000     233154.000000  ...      233154.000000
# mean        7.262243       1549.477148  ...           0.007244
# std         4.482230        975.261278  ...           0.111079
# min         1.000000          1.000000  ...           0.000000
# 25%         4.000000        713.000000  ...           0.000000
# 50%         6.000000       1451.000000  ...           0.000000
# 75%        10.000000       2362.000000  ...           0.000000
# max        22.000000       3795.000000  ...           8.000000
#
#        SEC_CURRENT_BALANCE  SEC_SANCTIONED_AMOUNT  SEC_DISBURSED_AMOUNT  \
# count         2.331540e+05           2.331540e+05          2.331540e+05
# mean          5.427793e+03           7.295923e+03          7.179998e+03
# std           1.702370e+05           1.831560e+05          1.825925e+05
# min          -5.746470e+05           0.000000e+00          0.000000e+00
# 25%           0.000000e+00           0.000000e+00          0.000000e+00
# 50%           0.000000e+00           0.000000e+00          0.000000e+00
# 75%           0.000000e+00           0.000000e+00          0.000000e+00
# max           3.603285e+07           3.000000e+07          3.000000e+07
#
#        PRIMARY_INSTAL_AMT  SEC_INSTAL_AMT  NEW_ACCTS_IN_LAST_SIX_MONTHS  \
# count        2.331540e+05    2.331540e+05                 233154.000000
# mean         1.310548e+04    3.232684e+02                      0.381833
# std          1.513679e+05    1.555369e+04                      0.955107
# min          0.000000e+00    0.000000e+00                      0.000000
# 25%          0.000000e+00    0.000000e+00                      0.000000
# 50%          0.000000e+00    0.000000e+00                      0.000000
# 75%          1.999000e+03    0.000000e+00                      0.000000
# max          2.564281e+07    4.170901e+06                     35.000000
#
#        DELINQUENT_ACCTS_IN_LAST_SIX_MONTHS  NO_OF_INQUIRIES   LOAN_DEFAULT
# count                        233154.000000    233154.000000  233154.000000
# mean                              0.097481         0.206615       0.217071
# std                               0.384439         0.706498       0.412252
# min                               0.000000         0.000000       0.000000
# 25%                               0.000000         0.000000       0.000000
# 50%                               0.000000         0.000000       0.000000
# 75%                               0.000000         0.000000       0.000000
# max                              20.000000        36.000000       1.000000
#
# [8 rows x 35 columns]

# %%
# drop agreed upon columns

colnames = ['DISBURSED_AMOUNT',
 'ASSET_COST',
 'DATE_OF_BIRTH',
 'EMPLOYMENT_TYPE',
 'DISBURSAL_DATE',
 'DRIVING_FLAG',
 'PERFORM_CNS_SCORE',
 'PRI_NO_OF_ACCTS',
 'PRI_ACTIVE_ACCTS',
 'PRI_OVERDUE_ACCTS',
 'PRI_CURRENT_BALANCE',
 'PRI_SANCTIONED_AMOUNT',
 'PRI_DISBURSED_AMOUNT',
 'SEC_NO_OF_ACCTS',
 'SEC_ACTIVE_ACCTS',
 'SEC_OVERDUE_ACCTS',
 'SEC_CURRENT_BALANCE',
 'SEC_SANCTIONED_AMOUNT',
 'SEC_DISBURSED_AMOUNT',
 'PRIMARY_INSTAL_AMT',
 'SEC_INSTAL_AMT',
 'NEW_ACCTS_IN_LAST_SIX_MONTHS',
 'DELINQUENT_ACCTS_IN_LAST_SIX_MONTHS',
 'AVERAGE_ACCT_AGE',
 'CREDIT_HISTORY_LENGTH',
 'NO_OF_INQUIRIES',
 'LOAN_DEFAULT']

df.drop(df.columns.difference(colnames), axis=1, inplace=True)

# %% [markdown]
# <a id='transformation'></a>
# ## Data transformation
# <a href="#">Back to top</a>

# %%
df.select_dtypes(include=object)
# Out:
#        DATE_OF_BIRTH EMPLOYMENT_TYPE DISBURSAL_DATE AVERAGE_ACCT_AGE  \
# 0         01-01-1984        Salaried     03-08-2018        0yrs 0mon
# 1         31-07-1985   Self employed     26-09-2018       1yrs 11mon
# 2         24-08-1985   Self employed     01-08-2018        0yrs 0mon
# 3         30-12-1993   Self employed     26-10-2018        0yrs 8mon
# 4         09-12-1977   Self employed     26-09-2018        0yrs 0mon
# ...              ...             ...            ...              ...
# 233149    01-08-1988        Salaried     26-10-2018        1yrs 9mon
# 233150    05-12-1988   Self employed     23-10-2018        0yrs 6mon
# 233151    01-06-1976        Salaried     24-10-2018        0yrs 0mon
# 233152    26-03-1994        Salaried     29-09-2018        0yrs 0mon
# 233153    18-02-1984        Salaried     27-10-2018        0yrs 0mon
#
#        CREDIT_HISTORY_LENGTH
# 0                  0yrs 0mon
# 1                 1yrs 11mon
# 2                  0yrs 0mon
# 3                  1yrs 3mon
# 4                  0yrs 0mon
# ...                      ...
# 233149             3yrs 3mon
# 233150             0yrs 6mon
# 233151             0yrs 0mon
# 233152             0yrs 0mon
# 233153             0yrs 0mon
#
# [233154 rows x 5 columns]

# %%
# convert dates so that we can have years-months-days format to manipulate

df['DATE_OF_BIRTH'] = pd.to_datetime(df['DATE_OF_BIRTH'])
df['DISBURSAL_DATE'] = pd.to_datetime(df['DISBURSAL_DATE'])

# %%
# convert dates to years? or days? I think days is better so that we dont have to worry about decimal points

# convert back to string to manipulate dates and remove "-" sign so that we can substract using Timestamp
df['DATE_OF_BIRTH'] = df['DATE_OF_BIRTH'].apply(lambda x: str(x).replace("-",""))
df['DISBURSAL_DATE'] = df['DISBURSAL_DATE'].apply(lambda x: str(x).replace("-",""))

df['DATE_OF_BIRTH'] = df['DATE_OF_BIRTH'].apply(lambda x: x.split()[0])
df['DISBURSAL_DATE'] = df['DISBURSAL_DATE'].apply(lambda x: x.split()[0])

# use timestamp to substract
df['DATE_OF_BIRTH'] = df['DATE_OF_BIRTH'].apply(lambda x: pd.Timestamp(x))
df['DISBURSAL_DATE'] = df['DISBURSAL_DATE'].apply(lambda x: pd.Timestamp(x))

# hard input todays date in a new column and subtract from dates column

df['TODAYS_DATE'] = pd.Timestamp('20211214')

df['LOANEE_DOB_DAYS'] = (df['TODAYS_DATE'] - df['DATE_OF_BIRTH']).dt.days
df['DISBURSAL_DATE_DAYS'] = (df['TODAYS_DATE'] - df['DISBURSAL_DATE']).dt.days

# drop TODAYS_DATE, DATE_OF_BIRTH, DISBURSAL_DATE column
drop_col = ['TODAYS_DATE','DATE_OF_BIRTH', 'DISBURSAL_DATE']
df.drop(columns=drop_col, axis=1, inplace=True)

# %%
# convert ages to days

df['AVERAGE_ACCT_AGE_DAYS'] = df['AVERAGE_ACCT_AGE'].apply(lambda x: (int(x.split()[0].replace("yrs",""))*365) + (int(x.split()[1].replace("mon",""))*30))
df['CREDIT_HISTORY_LENGTH_DAYS'] = df["CREDIT_HISTORY_LENGTH"].apply(lambda x: (int(x.split()[0].replace("yrs",""))*365) + (int(x.split()[1].replace("mon",""))*30))

# drop AVERAGE_ACCT_AGE, CREDIT_HISTORY_LENGTH
df.drop(columns=['AVERAGE_ACCT_AGE', 'CREDIT_HISTORY_LENGTH'], axis=1, inplace=True)

# %%
df
# Out:
#         DISBURSED_AMOUNT  ASSET_COST EMPLOYMENT_TYPE  DRIVING_FLAG  \
# 0                  50578       58400        Salaried             0
# 1                  47145       65550   Self employed             0
# 2                  53278       61360   Self employed             0
# 3                  57513       66113   Self employed             0
# 4                  52378       60300   Self employed             0
# ...                  ...         ...             ...           ...
# 233149             63213      105405        Salaried             0
# 233150             73651      100600   Self employed             0
# 233151             33484       71212        Salaried             0
# 233152             34259       73286        Salaried             0
# 233153             75751      116009        Salaried             0
#
#         PERFORM_CNS_SCORE  PRI_NO_OF_ACCTS  PRI_ACTIVE_ACCTS  \
# 0                       0                0                 0
# 1                     598                1                 1
# 2                       0                0                 0
# 3                     305                3                 0
# 4                       0                0                 0
# ...                   ...              ...               ...
# 233149                735                4                 3
# 233150                825                1                 0
# 233151                  0                0                 0
# 233152                  0                0                 0
# 233153                  0                0                 0
#
#         PRI_OVERDUE_ACCTS  PRI_CURRENT_BALANCE  PRI_SANCTIONED_AMOUNT  ...  \
# 0                       0                    0                      0  ...
# 1                       1                27600                  50200  ...
# 2                       0                    0                      0  ...
# 3                       0                    0                      0  ...
# 4                       0                    0                      0  ...
# ...                   ...                  ...                    ...  ...
# 233149                  0               390443                 416133  ...
# 233150                  0                    0                      0  ...
# 233151                  0                    0                      0  ...
# 233152                  0                    0                      0  ...
# 233153                  0                    0                      0  ...
#
#         PRIMARY_INSTAL_AMT  SEC_INSTAL_AMT  NEW_ACCTS_IN_LAST_SIX_MONTHS  \
# 0                        0               0                             0
# 1                     1991               0                             0
# 2                        0               0                             0
# 3                       31               0                             0
# 4                        0               0                             0
# ...                    ...             ...                           ...
# 233149                4084               0                             0
# 233150                1565               0                             0
# 233151                   0               0                             0
# 233152                   0               0                             0
# 233153                   0               0                             0
#
#         DELINQUENT_ACCTS_IN_LAST_SIX_MONTHS  NO_OF_INQUIRIES  LOAN_DEFAULT  \
# 0                                         0                0             0
# 1                                         1                0             1
# 2                                         0                0             0
# 3                                         0                1             1
# 4                                         0                1             1
# ...                                     ...              ...           ...
# 233149                                    0                0             0
# 233150                                    0                0             0
# 233151                                    0                0             0
# 233152                                    0                0             0
# 233153                                    0                0             0
#
#         LOANEE_DOB_DAYS  DISBURSAL_DATE_DAYS  AVERAGE_ACCT_AGE_DAYS  \
# 0                 13862                 1377                      0
# 1                 13285                 1175                    695
# 2                 13261                 1436                      0
# 3                 10211                 1145                    240
# 4                 16164                 1175                      0
# ...                 ...                  ...                    ...
# 233149            12394                 1145                    635
# 233150            12269                 1148                    180
# 233151            16779                 1147                      0
# 233152            10125                 1172                      0
# 233153            13814                 1144                      0
#
#         CREDIT_HISTORY_LENGTH_DAYS
# 0                                0
# 1                              695
# 2                                0
# 3                              455
# 4                                0
# ...                            ...
# 233149                        1185
# 233150                         180
# 233151                           0
# 233152                           0
# 233153                           0
#
# [233154 rows x 27 columns]

# %% [markdown]
# ## Outlier exploration and handling
# <a id='outlier'></a>
# <a href="#">Back to top</a>

# %%
numerical = df.select_dtypes(exclude=object)

# %%
def outlier_checker(df, col):
    q1 = df[col].quantile(0.25)
    q3 = df[col].quantile(0.75)
    IQR = q3 - q1
    LL = q1 - 1.5 * IQR
    UL = q3 + 1.5 * IQR
    return LL, UL

for i in numerical.columns:
    print(i, outlier_checker(df, i))
# Out:
# DISBURSED_AMOUNT (27243.0, 80315.0)
# ASSET_COST (45489.875, 99428.875)
# DRIVING_FLAG (0.0, 0.0)
# PERFORM_CNS_SCORE (-1017.0, 1695.0)
# PRI_NO_OF_ACCTS (-4.5, 7.5)
# PRI_ACTIVE_ACCTS (-1.5, 2.5)
# PRI_OVERDUE_ACCTS (0.0, 0.0)
# PRI_CURRENT_BALANCE (-52509.75, 87516.25)
# PRI_SANCTIONED_AMOUNT (-93750.0, 156250.0)
# PRI_DISBURSED_AMOUNT (-91200.0, 152000.0)
# SEC_NO_OF_ACCTS (0.0, 0.0)
# SEC_ACTIVE_ACCTS (0.0, 0.0)
# SEC_OVERDUE_ACCTS (0.0, 0.0)
# SEC_CURRENT_BALANCE (0.0, 0.0)
# SEC_SANCTIONED_AMOUNT (0.0, 0.0)
# SEC_DISBURSED_AMOUNT (0.0, 0.0)
# PRIMARY_INSTAL_AMT (-2998.5, 4997.5)
# SEC_INSTAL_AMT (0.0, 0.0)
# NEW_ACCTS_IN_LAST_SIX_MONTHS (0.0, 0.0)
# DELINQUENT_ACCTS_IN_LAST_SIX_MONTHS (0.0, 0.0)
# NO_OF_INQUIRIES (0.0, 0.0)
# LOAN_DEFAULT (0.0, 0.0)
# LOANEE_DOB_DAYS (2529.0, 24601.0)
# DISBURSAL_DATE_DAYS (1059.5, 1295.5)
# AVERAGE_ACCT_AGE_DAYS (-592.5, 987.5)
# CREDIT_HISTORY_LENGTH_DAYS (-1095.0, 1825.0)

# %%
def boxplot_plot(df, col):
    plt.boxplot(x=col, vert=False, data=df)
    plt.show()

# %%
for i in numerical.columns:
    print(i)
    boxplot_plot(df, i)
# Out:
# DISBURSED_AMOUNT
# ASSET_COST
# DRIVING_FLAG
# PERFORM_CNS_SCORE
# PRI_NO_OF_ACCTS
# PRI_ACTIVE_ACCTS
# PRI_OVERDUE_ACCTS
# PRI_CURRENT_BALANCE
# PRI_SANCTIONED_AMOUNT
# PRI_DISBURSED_AMOUNT
# SEC_NO_OF_ACCTS
# SEC_ACTIVE_ACCTS
# SEC_OVERDUE_ACCTS
# SEC_CURRENT_BALANCE
# SEC_SANCTIONED_AMOUNT
# SEC_DISBURSED_AMOUNT
# PRIMARY_INSTAL_AMT
# SEC_INSTAL_AMT
# NEW_ACCTS_IN_LAST_SIX_MONTHS
# DELINQUENT_ACCTS_IN_LAST_SIX_MONTHS
# NO_OF_INQUIRIES
# LOAN_DEFAULT
# LOANEE_DOB_DAYS
# DISBURSAL_DATE_DAYS
# AVERAGE_ACCT_AGE_DAYS
# CREDIT_HISTORY_LENGTH_DAYS

# %%
# def outlier_remover(df, col):
#     q1 = df[col].quantile(0.25)
#     q3 = df[col].quantile(0.75)
#     IQR = q3 - q1
#     LL = q1 - 1.5 * IQR
#     UL = q3 + 1.5 * IQR
#     df = df[df[col] < UL]
#     df = df[df[col] > LL]
#     return df

# %%
# Hard remove outliers

# remove outlier of disbusred
df.drop(index=df[df['PRI_DISBURSED_AMOUNT'] > 7000000].index, axis=0, inplace=True)

# remove outliers of NO_OF_ACCTS that are greater than 7.5 (total loans at the time of disbursement)
df.drop(index=df[df['PRI_NO_OF_ACCTS'] > 10].index, axis=0, inplace=True)

# remove outliers of ACTIVE_ACCTS greater than 5 (active loans at the time of disburesment)
df.drop(index=df[df['PRI_ACTIVE_ACCTS'] > 5].index, axis=0, inplace=True)

# %%
plt.boxplot(x='PRI_NO_OF_ACCTS', data=df, vert=False);

# %%
plt.boxplot(x='PRI_ACTIVE_ACCTS', data=df, vert=False);

# %%
df.shape
# Out:
# (217506, 27)

# %% [markdown]
# ## Check nulls

# %%
# check null percentage
df.isna().sum()/len(df)*100
# Out:
# DISBURSED_AMOUNT                       0.00000
# ASSET_COST                             0.00000
# EMPLOYMENT_TYPE                        3.33554
# DRIVING_FLAG                           0.00000
# PERFORM_CNS_SCORE                      0.00000
# PRI_NO_OF_ACCTS                        0.00000
# PRI_ACTIVE_ACCTS                       0.00000
# PRI_OVERDUE_ACCTS                      0.00000
# PRI_CURRENT_BALANCE                    0.00000
# PRI_SANCTIONED_AMOUNT                  0.00000
# PRI_DISBURSED_AMOUNT                   0.00000
# SEC_NO_OF_ACCTS                        0.00000
# SEC_ACTIVE_ACCTS                       0.00000
# SEC_OVERDUE_ACCTS                      0.00000
# SEC_CURRENT_BALANCE                    0.00000
# SEC_SANCTIONED_AMOUNT                  0.00000
# SEC_DISBURSED_AMOUNT                   0.00000
# PRIMARY_INSTAL_AMT                     0.00000
# SEC_INSTAL_AMT                         0.00000
# NEW_ACCTS_IN_LAST_SIX_MONTHS           0.00000
# DELINQUENT_ACCTS_IN_LAST_SIX_MONTHS    0.00000
# NO_OF_INQUIRIES                        0.00000
# LOAN_DEFAULT                           0.00000
# LOANEE_DOB_DAYS                        0.00000
# DISBURSAL_DATE_DAYS                    0.00000
# AVERAGE_ACCT_AGE_DAYS                  0.00000
# CREDIT_HISTORY_LENGTH_DAYS             0.00000
# dtype: float64

# %%
# fill nulls with mode
emp_mode = df['EMPLOYMENT_TYPE'].mode()
df['EMPLOYMENT_TYPE'].fillna(emp_mode[0], inplace=True)

# %%
df['EMPLOYMENT_TYPE'].isna().sum()/len(df)*100
# Out:
# 0.0

# %% [markdown]
# ## Feature Engineering
# <a id='feature'></a>
# <a href="#">Back to top</a>

# %%
df['PERFORM_CNS_SCORE']
# Out:
# 0           0
# 1         598
# 2           0
# 3         305
# 4           0
#          ...
# 233149    735
# 233150    825
# 233151      0
# 233152      0
# 233153      0
# Name: PERFORM_CNS_SCORE, Length: 217506, dtype: int64

# %%
# binning PERFORM_CNS_SCORE to 5 bins, (very_low, low, medium, high, very_high)
labels = ["Very low", "Low", "Medium", "High", "Very high"]
df['PERFORM_CNS_DESC'] = pd.cut(df['PERFORM_CNS_SCORE'], 5, labels=labels)
df.groupby('PERFORM_CNS_DESC')['PERFORM_CNS_SCORE'].agg(['min', 'max', 'count'])
# Out:
#                   min  max   count
# PERFORM_CNS_DESC
# Very low            0   18  129661
# Low               300  356    7878
# Medium            357  534    6638
# High              535  712   32102
# Very high         713  890   41227

# %% [markdown]
# > Verify binning

# %%
df[df['PERFORM_CNS_SCORE'] < df['PERFORM_CNS_SCORE'].max()/5]['PERFORM_CNS_SCORE'].max()
# Out:
# 18

# %%
df[df['PERFORM_CNS_SCORE'] < (df['PERFORM_CNS_SCORE'].max()/5)*2]['PERFORM_CNS_SCORE'].max()
# Out:
# 355

# %%
df[df['PERFORM_CNS_SCORE'] < (df['PERFORM_CNS_SCORE'].max()/5)*3]['PERFORM_CNS_SCORE'].max()
# Out:
# 533

# %%
df[df['PERFORM_CNS_SCORE'] < (df['PERFORM_CNS_SCORE'].max()/5)*4]['PERFORM_CNS_SCORE'].max()
# Out:
# 711

# %%
df.drop(columns='PERFORM_CNS_SCORE', axis=1, inplace=True)

# %%
df.shape
# Out:
# (217506, 27)

# %%
# Extract new feature called loan to asset ratio (LTA)

df['LTA'] = round(df['DISBURSED_AMOUNT']/df['ASSET_COST']*100, 2)

# %%
df.shape
# Out:
# (217506, 28)

# %% [markdown]
# ### Convert categorical to dummy variables
# <a id='dummy'></a>
# <a href="#">Back to top</a>

# %%
# convert dummy variables of EMPLOYMENT_TYPE and PERFORM_CNS_DESC

df = pd.get_dummies(df, drop_first=True)

# %%
df
# Out:
#         DISBURSED_AMOUNT  ASSET_COST  DRIVING_FLAG  PRI_NO_OF_ACCTS  \
# 0                  50578       58400             0                0
# 1                  47145       65550             0                1
# 2                  53278       61360             0                0
# 3                  57513       66113             0                3
# 4                  52378       60300             0                0
# ...                  ...         ...           ...              ...
# 233149             63213      105405             0                4
# 233150             73651      100600             0                1
# 233151             33484       71212             0                0
# 233152             34259       73286             0                0
# 233153             75751      116009             0                0
#
#         PRI_ACTIVE_ACCTS  PRI_OVERDUE_ACCTS  PRI_CURRENT_BALANCE  \
# 0                      0                  0                    0
# 1                      1                  1                27600
# 2                      0                  0                    0
# 3                      0                  0                    0
# 4                      0                  0                    0
# ...                  ...                ...                  ...
# 233149                 3                  0               390443
# 233150                 0                  0                    0
# 233151                 0                  0                    0
# 233152                 0                  0                    0
# 233153                 0                  0                    0
#
#         PRI_SANCTIONED_AMOUNT  PRI_DISBURSED_AMOUNT  SEC_NO_OF_ACCTS  ...  \
# 0                           0                     0                0  ...
# 1                       50200                 50200                0  ...
# 2                           0                     0                0  ...
# 3                           0                     0                0  ...
# 4                           0                     0                0  ...
# ...                       ...                   ...              ...  ...
# 233149                 416133                416133                0  ...
# 233150                      0                     0                0  ...
# 233151                      0                     0                0  ...
# 233152                      0                     0                0  ...
# 233153                      0                     0                0  ...
#
#         LOANEE_DOB_DAYS  DISBURSAL_DATE_DAYS  AVERAGE_ACCT_AGE_DAYS  \
# 0                 13862                 1377                      0
# 1                 13285                 1175                    695
# 2                 13261                 1436                      0
# 3                 10211                 1145                    240
# 4                 16164                 1175                      0
# ...                 ...                  ...                    ...
# 233149            12394                 1145                    635
# 233150            12269                 1148                    180
# 233151            16779                 1147                      0
# 233152            10125                 1172                      0
# 233153            13814                 1144                      0
#
#         CREDIT_HISTORY_LENGTH_DAYS    LTA  EMPLOYMENT_TYPE_Self employed  \
# 0                                0  86.61                              0
# 1                              695  71.92                              1
# 2                                0  86.83                              1
# 3                              455  86.99                              1
# 4                                0  86.86                              1
# ...                            ...    ...                            ...
# 233149                        1185  59.97                              0
# 233150                         180  73.21                              1
# 233151                           0  47.02                              0
# 233152                           0  46.75                              0
# 233153                           0  65.30                              0
#
#         PERFORM_CNS_DESC_Low  PERFORM_CNS_DESC_Medium  PERFORM_CNS_DESC_High  \
# 0                          0                        0                      0
# 1                          0                        0                      1
# 2                          0                        0                      0
# 3                          1                        0                      0
# 4                          0                        0                      0
# ...                      ...                      ...                    ...
# 233149                     0                        0                      0
# 233150                     0                        0                      0
# 233151                     0                        0                      0
# 233152                     0                        0                      0
# 233153                     0                        0                      0
#
#         PERFORM_CNS_DESC_Very high
# 0                                0
# 1                                0
# 2                                0
# 3                                0
# 4                                0
# ...                            ...
# 233149                           1
# 233150                           1
# 233151                           0
# 233152                           0
# 233153                           0
#
# [217506 rows x 31 columns]

# %%
df.shape
# Out:
# (217506, 31)

# %%
# Export to csv
df.to_csv("../data/interim/data.csv", index=False)

# %%
# correlation dataframe
df.corr()
# Out:
#                                      DISBURSED_AMOUNT  ASSET_COST  \
# DISBURSED_AMOUNT                             1.000000    0.744298
# ASSET_COST                                   0.744298    1.000000
# DRIVING_FLAG                                 0.001367    0.021637
# PRI_NO_OF_ACCTS                              0.020891   -0.040519
# PRI_ACTIVE_ACCTS                             0.027527   -0.024782
# PRI_OVERDUE_ACCTS                            0.013440   -0.015074
# PRI_CURRENT_BALANCE                          0.008995   -0.005722
# PRI_SANCTIONED_AMOUNT                        0.010237   -0.004194
# PRI_DISBURSED_AMOUNT                         0.010767   -0.004297
# SEC_NO_OF_ACCTS                             -0.014559   -0.021815
# SEC_ACTIVE_ACCTS                            -0.014066   -0.019626
# SEC_OVERDUE_ACCTS                           -0.006558   -0.012778
# SEC_CURRENT_BALANCE                         -0.004546   -0.008966
# SEC_SANCTIONED_AMOUNT                       -0.005838   -0.011193
# SEC_DISBURSED_AMOUNT                        -0.005679   -0.010993
# PRIMARY_INSTAL_AMT                          -0.002720   -0.004778
# SEC_INSTAL_AMT                              -0.004135   -0.004575
# NEW_ACCTS_IN_LAST_SIX_MONTHS                 0.024101   -0.024539
# DELINQUENT_ACCTS_IN_LAST_SIX_MONTHS          0.012032   -0.008550
# NO_OF_INQUIRIES                              0.034594   -0.017233
# LOAN_DEFAULT                                 0.082430    0.014720
# LOANEE_DOB_DAYS                             -0.066404   -0.121675
# DISBURSAL_DATE_DAYS                         -0.076805   -0.071426
# AVERAGE_ACCT_AGE_DAYS                        0.000806   -0.015346
# CREDIT_HISTORY_LENGTH_DAYS                   0.003554   -0.023038
# LTA                                          0.399730   -0.292783
# EMPLOYMENT_TYPE_Self employed               -0.011959    0.070937
# PERFORM_CNS_DESC_Low                         0.010698   -0.013438
# PERFORM_CNS_DESC_Medium                      0.006992   -0.003604
# PERFORM_CNS_DESC_High                        0.022141   -0.009521
# PERFORM_CNS_DESC_Very high                  -0.014467   -0.041684
#
#                                      DRIVING_FLAG  PRI_NO_OF_ACCTS  \
# DISBURSED_AMOUNT                         0.001367         0.020891
# ASSET_COST                               0.021637        -0.040519
# DRIVING_FLAG                             1.000000         0.008833
# PRI_NO_OF_ACCTS                          0.008833         1.000000
# PRI_ACTIVE_ACCTS                         0.009681         0.804423
# PRI_OVERDUE_ACCTS                        0.010359         0.358734
# PRI_CURRENT_BALANCE                      0.004564         0.329276
# PRI_SANCTIONED_AMOUNT                    0.007038         0.383173
# PRI_DISBURSED_AMOUNT                     0.007213         0.381612
# SEC_NO_OF_ACCTS                          0.002200         0.065953
# SEC_ACTIVE_ACCTS                         0.003710         0.056468
# SEC_OVERDUE_ACCTS                        0.002434         0.042433
# SEC_CURRENT_BALANCE                      0.001388         0.020740
# SEC_SANCTIONED_AMOUNT                    0.001697         0.026111
# SEC_DISBURSED_AMOUNT                     0.001702         0.025581
# PRIMARY_INSTAL_AMT                       0.001906         0.123146
# SEC_INSTAL_AMT                          -0.001185         0.016152
# NEW_ACCTS_IN_LAST_SIX_MONTHS            -0.003035         0.501059
# DELINQUENT_ACCTS_IN_LAST_SIX_MONTHS      0.009854         0.290780
# NO_OF_INQUIRIES                         -0.019894         0.195766
# LOAN_DEFAULT                            -0.005387        -0.033573
# LOANEE_DOB_DAYS                         -0.007456         0.192163
# DISBURSAL_DATE_DAYS                      0.018421         0.003645
# AVERAGE_ACCT_AGE_DAYS                    0.017647         0.389230
# CREDIT_HISTORY_LENGTH_DAYS               0.018917         0.562775
# LTA                                     -0.027095         0.088860
# EMPLOYMENT_TYPE_Self employed            0.000857        -0.026077
# PERFORM_CNS_DESC_Low                     0.004594         0.211039
# PERFORM_CNS_DESC_Medium                  0.009895         0.201165
# PERFORM_CNS_DESC_High                    0.006258         0.401887
# PERFORM_CNS_DESC_Very high              -0.000731         0.326378
#
#                                      PRI_ACTIVE_ACCTS  PRI_OVERDUE_ACCTS  \
# DISBURSED_AMOUNT                             0.027527           0.013440
# ASSET_COST                                  -0.024782          -0.015074
# DRIVING_FLAG                                 0.009681           0.010359
# PRI_NO_OF_ACCTS                              0.804423           0.358734
# PRI_ACTIVE_ACCTS                             1.000000           0.354970
# PRI_OVERDUE_ACCTS                            0.354970           1.000000
# PRI_CURRENT_BALANCE                          0.403411           0.196735
# PRI_SANCTIONED_AMOUNT                        0.466037           0.226057
# PRI_DISBURSED_AMOUNT                         0.463865           0.227744
# SEC_NO_OF_ACCTS                              0.057261           0.045474
# SEC_ACTIVE_ACCTS                             0.051799           0.039102
# SEC_OVERDUE_ACCTS                            0.037167           0.041400
# SEC_CURRENT_BALANCE                          0.020305           0.009941
# SEC_SANCTIONED_AMOUNT                        0.024878           0.014435
# SEC_DISBURSED_AMOUNT                         0.024323           0.014035
# PRIMARY_INSTAL_AMT                           0.091489           0.046001
# SEC_INSTAL_AMT                               0.012583           0.006625
# NEW_ACCTS_IN_LAST_SIX_MONTHS                 0.639105           0.057013
# DELINQUENT_ACCTS_IN_LAST_SIX_MONTHS          0.327119           0.422161
# NO_OF_INQUIRIES                              0.197023           0.052044
# LOAN_DEFAULT                                -0.025172           0.053612
# LOANEE_DOB_DAYS                              0.135433           0.124758
# DISBURSAL_DATE_DAYS                          0.007177           0.007436
# AVERAGE_ACCT_AGE_DAYS                        0.375833           0.349383
# CREDIT_HISTORY_LENGTH_DAYS                   0.514911           0.420376
# LTA                                          0.076692           0.043177
# EMPLOYMENT_TYPE_Self employed               -0.033283           0.014173
# PERFORM_CNS_DESC_Low                         0.179393           0.591629
# PERFORM_CNS_DESC_Medium                      0.219400           0.404525
# PERFORM_CNS_DESC_High                        0.447246           0.078890
# PERFORM_CNS_DESC_Very high                   0.238321          -0.120376
#
#                                      PRI_CURRENT_BALANCE  \
# DISBURSED_AMOUNT                                0.008995
# ASSET_COST                                     -0.005722
# DRIVING_FLAG                                    0.004564
# PRI_NO_OF_ACCTS                                 0.329276
# PRI_ACTIVE_ACCTS                                0.403411
# PRI_OVERDUE_ACCTS                               0.196735
# PRI_CURRENT_BALANCE                             1.000000
# PRI_SANCTIONED_AMOUNT                           0.925904
# PRI_DISBURSED_AMOUNT                            0.929117
# SEC_NO_OF_ACCTS                                 0.022520
# SEC_ACTIVE_ACCTS                                0.016519
# SEC_OVERDUE_ACCTS                               0.012312
# SEC_CURRENT_BALANCE                             0.005814
# SEC_SANCTIONED_AMOUNT                           0.008123
# SEC_DISBURSED_AMOUNT                            0.007965
# PRIMARY_INSTAL_AMT                              0.100250
# SEC_INSTAL_AMT                                  0.006288
# NEW_ACCTS_IN_LAST_SIX_MONTHS                    0.167979
# DELINQUENT_ACCTS_IN_LAST_SIX_MONTHS             0.192804
# NO_OF_INQUIRIES                                 0.018810
# LOAN_DEFAULT                                   -0.029339
# LOANEE_DOB_DAYS                                 0.104049
# DISBURSAL_DATE_DAYS                             0.001727
# AVERAGE_ACCT_AGE_DAYS                           0.210290
# CREDIT_HISTORY_LENGTH_DAYS                      0.282710
# LTA                                             0.021602
# EMPLOYMENT_TYPE_Self employed                   0.000754
# PERFORM_CNS_DESC_Low                            0.080698
# PERFORM_CNS_DESC_Medium                         0.135535
# PERFORM_CNS_DESC_High                           0.174777
# PERFORM_CNS_DESC_Very high                      0.082190
#
#                                      PRI_SANCTIONED_AMOUNT  \
# DISBURSED_AMOUNT                                  0.010237
# ASSET_COST                                       -0.004194
# DRIVING_FLAG                                      0.007038
# PRI_NO_OF_ACCTS                                   0.383173
# PRI_ACTIVE_ACCTS                                  0.466037
# PRI_OVERDUE_ACCTS                                 0.226057
# PRI_CURRENT_BALANCE                               0.925904
# PRI_SANCTIONED_AMOUNT                             1.000000
# PRI_DISBURSED_AMOUNT                              0.996915
# SEC_NO_OF_ACCTS                                   0.027314
# SEC_ACTIVE_ACCTS                                  0.020448
# SEC_OVERDUE_ACCTS                                 0.015068
# SEC_CURRENT_BALANCE                               0.008179
# SEC_SANCTIONED_AMOUNT                             0.010981
# SEC_DISBURSED_AMOUNT                              0.010795
# PRIMARY_INSTAL_AMT                                0.103003
# SEC_INSTAL_AMT                                    0.008178
# NEW_ACCTS_IN_LAST_SIX_MONTHS                      0.169325
# DELINQUENT_ACCTS_IN_LAST_SIX_MONTHS               0.212583
# NO_OF_INQUIRIES                                   0.017976
# LOAN_DEFAULT                                     -0.036340
# LOANEE_DOB_DAYS                                   0.125603
# DISBURSAL_DATE_DAYS                               0.003978
# AVERAGE_ACCT_AGE_DAYS                             0.264574
# CREDIT_HISTORY_LENGTH_DAYS                        0.346945
# LTA                                               0.021201
# EMPLOYMENT_TYPE_Self employed                    -0.000942
# PERFORM_CNS_DESC_Low                              0.089442
# PERFORM_CNS_DESC_Medium                           0.158598
# PERFORM_CNS_DESC_High                             0.196294
# PERFORM_CNS_DESC_Very high                        0.102895
#
#                                      PRI_DISBURSED_AMOUNT  SEC_NO_OF_ACCTS  \
# DISBURSED_AMOUNT                                 0.010767        -0.014559
# ASSET_COST                                      -0.004297        -0.021815
# DRIVING_FLAG                                     0.007213         0.002200
# PRI_NO_OF_ACCTS                                  0.381612         0.065953
# PRI_ACTIVE_ACCTS                                 0.463865         0.057261
# PRI_OVERDUE_ACCTS                                0.227744         0.045474
# PRI_CURRENT_BALANCE                              0.929117         0.022520
# PRI_SANCTIONED_AMOUNT                            0.996915         0.027314
# PRI_DISBURSED_AMOUNT                             1.000000         0.026788
# SEC_NO_OF_ACCTS                                  0.026788         1.000000
# SEC_ACTIVE_ACCTS                                 0.019927         0.833774
# SEC_OVERDUE_ACCTS                                0.014811         0.513299
# SEC_CURRENT_BALANCE                              0.007955         0.303376
# SEC_SANCTIONED_AMOUNT                            0.010714         0.387301
# SEC_DISBURSED_AMOUNT                             0.010540         0.381548
# PRIMARY_INSTAL_AMT                               0.104169         0.010141
# SEC_INSTAL_AMT                                   0.007941         0.222163
# NEW_ACCTS_IN_LAST_SIX_MONTHS                     0.168337         0.145601
# DELINQUENT_ACCTS_IN_LAST_SIX_MONTHS              0.212966         0.111936
# NO_OF_INQUIRIES                                  0.018608         0.002603
# LOAN_DEFAULT                                    -0.035742        -0.007094
# LOANEE_DOB_DAYS                                  0.125640         0.020305
# DISBURSAL_DATE_DAYS                              0.003195         0.022417
# AVERAGE_ACCT_AGE_DAYS                            0.263329         0.074719
# CREDIT_HISTORY_LENGTH_DAYS                       0.344967         0.156746
# LTA                                              0.022141         0.010890
# EMPLOYMENT_TYPE_Self employed                    0.000258        -0.005542
# PERFORM_CNS_DESC_Low                             0.090068         0.036725
# PERFORM_CNS_DESC_Medium                          0.159831         0.018793
# PERFORM_CNS_DESC_High                            0.197062         0.026547
# PERFORM_CNS_DESC_Very high                       0.100019         0.029763
#
#                                      ...  LOANEE_DOB_DAYS  \
# DISBURSED_AMOUNT                     ...        -0.066404
# ASSET_COST                           ...        -0.121675
# DRIVING_FLAG                         ...        -0.007456
# PRI_NO_OF_ACCTS                      ...         0.192163
# PRI_ACTIVE_ACCTS                     ...         0.135433
# PRI_OVERDUE_ACCTS                    ...         0.124758
# PRI_CURRENT_BALANCE                  ...         0.104049
# PRI_SANCTIONED_AMOUNT                ...         0.125603
# PRI_DISBURSED_AMOUNT                 ...         0.125640
# SEC_NO_OF_ACCTS                      ...         0.020305
# SEC_ACTIVE_ACCTS                     ...         0.013149
# SEC_OVERDUE_ACCTS                    ...         0.014575
# SEC_CURRENT_BALANCE                  ...         0.008140
# SEC_SANCTIONED_AMOUNT                ...         0.010005
# SEC_DISBURSED_AMOUNT                 ...         0.009975
# PRIMARY_INSTAL_AMT                   ...         0.037451
# SEC_INSTAL_AMT                       ...         0.008762
# NEW_ACCTS_IN_LAST_SIX_MONTHS         ...         0.008935
# DELINQUENT_ACCTS_IN_LAST_SIX_MONTHS  ...         0.059567
# NO_OF_INQUIRIES                      ...        -0.012522
# LOAN_DEFAULT                         ...        -0.032869
# LOANEE_DOB_DAYS                      ...         1.000000
# DISBURSAL_DATE_DAYS                  ...        -0.001056
# AVERAGE_ACCT_AGE_DAYS                ...         0.237984
# CREDIT_HISTORY_LENGTH_DAYS           ...         0.256643
# LTA                                  ...         0.074677
# EMPLOYMENT_TYPE_Self employed        ...         0.057817
# PERFORM_CNS_DESC_Low                 ...         0.085320
# PERFORM_CNS_DESC_Medium              ...         0.064250
# PERFORM_CNS_DESC_High                ...         0.072662
# PERFORM_CNS_DESC_Very high           ...         0.082870
#
#                                      DISBURSAL_DATE_DAYS  \
# DISBURSED_AMOUNT                               -0.076805
# ASSET_COST                                     -0.071426
# DRIVING_FLAG                                    0.018421
# PRI_NO_OF_ACCTS                                 0.003645
# PRI_ACTIVE_ACCTS                                0.007177
# PRI_OVERDUE_ACCTS                               0.007436
# PRI_CURRENT_BALANCE                             0.001727
# PRI_SANCTIONED_AMOUNT                           0.003978
# PRI_DISBURSED_AMOUNT                            0.003195
# SEC_NO_OF_ACCTS                                 0.022417
# SEC_ACTIVE_ACCTS                                0.019840
# SEC_OVERDUE_ACCTS                               0.014824
# SEC_CURRENT_BALANCE                             0.008046
# SEC_SANCTIONED_AMOUNT                           0.010448
# SEC_DISBURSED_AMOUNT                            0.010317
# PRIMARY_INSTAL_AMT                              0.003266
# SEC_INSTAL_AMT                                  0.005957
# NEW_ACCTS_IN_LAST_SIX_MONTHS                   -0.000486
# DELINQUENT_ACCTS_IN_LAST_SIX_MONTHS             0.005767
# NO_OF_INQUIRIES                                -0.009733
# LOAN_DEFAULT                                   -0.011526
# LOANEE_DOB_DAYS                                -0.001056
# DISBURSAL_DATE_DAYS                             1.000000
# AVERAGE_ACCT_AGE_DAYS                           0.006973
# CREDIT_HISTORY_LENGTH_DAYS                      0.009453
# LTA                                            -0.000371
# EMPLOYMENT_TYPE_Self employed                  -0.008968
# PERFORM_CNS_DESC_Low                            0.009823
# PERFORM_CNS_DESC_Medium                         0.000002
# PERFORM_CNS_DESC_High                          -0.002678
# PERFORM_CNS_DESC_Very high                      0.001374
#
#                                      AVERAGE_ACCT_AGE_DAYS  \
# DISBURSED_AMOUNT                                  0.000806
# ASSET_COST                                       -0.015346
# DRIVING_FLAG                                      0.017647
# PRI_NO_OF_ACCTS                                   0.389230
# PRI_ACTIVE_ACCTS                                  0.375833
# PRI_OVERDUE_ACCTS                                 0.349383
# PRI_CURRENT_BALANCE                               0.210290
# PRI_SANCTIONED_AMOUNT                             0.264574
# PRI_DISBURSED_AMOUNT                              0.263329
# SEC_NO_OF_ACCTS                                   0.074719
# SEC_ACTIVE_ACCTS                                  0.075881
# SEC_OVERDUE_ACCTS                                 0.077579
# SEC_CURRENT_BALANCE                               0.029254
# SEC_SANCTIONED_AMOUNT                             0.038647
# SEC_DISBURSED_AMOUNT                              0.038056
# PRIMARY_INSTAL_AMT                                0.044613
# SEC_INSTAL_AMT                                    0.012240
# NEW_ACCTS_IN_LAST_SIX_MONTHS                      0.018263
# DELINQUENT_ACCTS_IN_LAST_SIX_MONTHS               0.171524
# NO_OF_INQUIRIES                                   0.021331
# LOAN_DEFAULT                                     -0.019121
# LOANEE_DOB_DAYS                                   0.237984
# DISBURSAL_DATE_DAYS                               0.006973
# AVERAGE_ACCT_AGE_DAYS                             1.000000
# CREDIT_HISTORY_LENGTH_DAYS                        0.877221
# LTA                                               0.023990
# EMPLOYMENT_TYPE_Self employed                    -0.005839
# PERFORM_CNS_DESC_Low                              0.273252
# PERFORM_CNS_DESC_Medium                           0.188879
# PERFORM_CNS_DESC_High                             0.289124
# PERFORM_CNS_DESC_Very high                        0.216440
#
#                                      CREDIT_HISTORY_LENGTH_DAYS       LTA  \
# DISBURSED_AMOUNT                                       0.003554  0.399730
# ASSET_COST                                            -0.023038 -0.292783
# DRIVING_FLAG                                           0.018917 -0.027095
# PRI_NO_OF_ACCTS                                        0.562775  0.088860
# PRI_ACTIVE_ACCTS                                       0.514911  0.076692
# PRI_OVERDUE_ACCTS                                      0.420376  0.043177
# PRI_CURRENT_BALANCE                                    0.282710  0.021602
# PRI_SANCTIONED_AMOUNT                                  0.346945  0.021201
# PRI_DISBURSED_AMOUNT                                   0.344967  0.022141
# SEC_NO_OF_ACCTS                                        0.156746  0.010890
# SEC_ACTIVE_ACCTS                                       0.147020  0.008515
# SEC_OVERDUE_ACCTS                                      0.132802  0.008900
# SEC_CURRENT_BALANCE                                    0.058401  0.006529
# SEC_SANCTIONED_AMOUNT                                  0.074717  0.007873
# SEC_DISBURSED_AMOUNT                                   0.073569  0.007811
# PRIMARY_INSTAL_AMT                                     0.068351  0.001495
# SEC_INSTAL_AMT                                         0.033390  0.000676
# NEW_ACCTS_IN_LAST_SIX_MONTHS                           0.137450  0.071003
# DELINQUENT_ACCTS_IN_LAST_SIX_MONTHS                    0.222012  0.031491
# NO_OF_INQUIRIES                                        0.046140  0.078354
# LOAN_DEFAULT                                          -0.028835  0.102258
# LOANEE_DOB_DAYS                                        0.256643  0.074677
# DISBURSAL_DATE_DAYS                                    0.009453 -0.000371
# AVERAGE_ACCT_AGE_DAYS                                  0.877221  0.023990
# CREDIT_HISTORY_LENGTH_DAYS                             1.000000  0.038745
# LTA                                                    0.038745  1.000000
# EMPLOYMENT_TYPE_Self employed                         -0.014822 -0.117365
# PERFORM_CNS_DESC_Low                                   0.298595  0.036552
# PERFORM_CNS_DESC_Medium                                0.208049  0.016845
# PERFORM_CNS_DESC_High                                  0.296097  0.046765
# PERFORM_CNS_DESC_Very high                             0.208161  0.038176
#
#                                      EMPLOYMENT_TYPE_Self employed  \
# DISBURSED_AMOUNT                                         -0.011959
# ASSET_COST                                                0.070937
# DRIVING_FLAG                                              0.000857
# PRI_NO_OF_ACCTS                                          -0.026077
# PRI_ACTIVE_ACCTS                                         -0.033283
# PRI_OVERDUE_ACCTS                                         0.014173
# PRI_CURRENT_BALANCE                                       0.000754
# PRI_SANCTIONED_AMOUNT                                    -0.000942
# PRI_DISBURSED_AMOUNT                                      0.000258
# SEC_NO_OF_ACCTS                                          -0.005542
# SEC_ACTIVE_ACCTS                                         -0.006341
# SEC_OVERDUE_ACCTS                                        -0.000572
# SEC_CURRENT_BALANCE                                      -0.002518
# SEC_SANCTIONED_AMOUNT                                    -0.003504
# SEC_DISBURSED_AMOUNT                                     -0.003499
# PRIMARY_INSTAL_AMT                                        0.009487
# SEC_INSTAL_AMT                                           -0.004857
# NEW_ACCTS_IN_LAST_SIX_MONTHS                             -0.027956
# DELINQUENT_ACCTS_IN_LAST_SIX_MONTHS                      -0.001595
# NO_OF_INQUIRIES                                          -0.008831
# LOAN_DEFAULT                                              0.027194
# LOANEE_DOB_DAYS                                           0.057817
# DISBURSAL_DATE_DAYS                                      -0.008968
# AVERAGE_ACCT_AGE_DAYS                                    -0.005839
# CREDIT_HISTORY_LENGTH_DAYS                               -0.014822
# LTA                                                      -0.117365
# EMPLOYMENT_TYPE_Self employed                             1.000000
# PERFORM_CNS_DESC_Low                                      0.015703
# PERFORM_CNS_DESC_Medium                                   0.007369
# PERFORM_CNS_DESC_High                                    -0.019387
# PERFORM_CNS_DESC_Very high                               -0.052068
#
#                                      PERFORM_CNS_DESC_Low  \
# DISBURSED_AMOUNT                                 0.010698
# ASSET_COST                                      -0.013438
# DRIVING_FLAG                                     0.004594
# PRI_NO_OF_ACCTS                                  0.211039
# PRI_ACTIVE_ACCTS                                 0.179393
# PRI_OVERDUE_ACCTS                                0.591629
# PRI_CURRENT_BALANCE                              0.080698
# PRI_SANCTIONED_AMOUNT                            0.089442
# PRI_DISBURSED_AMOUNT                             0.090068
# SEC_NO_OF_ACCTS                                  0.036725
# SEC_ACTIVE_ACCTS                                 0.032074
# SEC_OVERDUE_ACCTS                                0.035763
# SEC_CURRENT_BALANCE                              0.007093
# SEC_SANCTIONED_AMOUNT                            0.010949
# SEC_DISBURSED_AMOUNT                             0.010616
# PRIMARY_INSTAL_AMT                               0.020691
# SEC_INSTAL_AMT                                   0.008448
# NEW_ACCTS_IN_LAST_SIX_MONTHS                    -0.004976
# DELINQUENT_ACCTS_IN_LAST_SIX_MONTHS              0.163927
# NO_OF_INQUIRIES                                  0.037728
# LOAN_DEFAULT                                     0.044125
# LOANEE_DOB_DAYS                                  0.085320
# DISBURSAL_DATE_DAYS                              0.009823
# AVERAGE_ACCT_AGE_DAYS                            0.273252
# CREDIT_HISTORY_LENGTH_DAYS                       0.298595
# LTA                                              0.036552
# EMPLOYMENT_TYPE_Self employed                    0.015703
# PERFORM_CNS_DESC_Low                             1.000000
# PERFORM_CNS_DESC_Medium                         -0.034395
# PERFORM_CNS_DESC_High                           -0.080666
# PERFORM_CNS_DESC_Very high                      -0.093751
#
#                                      PERFORM_CNS_DESC_Medium  \
# DISBURSED_AMOUNT                                    0.006992
# ASSET_COST                                         -0.003604
# DRIVING_FLAG                                        0.009895
# PRI_NO_OF_ACCTS                                     0.201165
# PRI_ACTIVE_ACCTS                                    0.219400
# PRI_OVERDUE_ACCTS                                   0.404525
# PRI_CURRENT_BALANCE                                 0.135535
# PRI_SANCTIONED_AMOUNT                               0.158598
# PRI_DISBURSED_AMOUNT                                0.159831
# SEC_NO_OF_ACCTS                                     0.018793
# SEC_ACTIVE_ACCTS                                    0.016835
# SEC_OVERDUE_ACCTS                                   0.012381
# SEC_CURRENT_BALANCE                                 0.004115
# SEC_SANCTIONED_AMOUNT                               0.005470
# SEC_DISBURSED_AMOUNT                                0.005143
# PRIMARY_INSTAL_AMT                                  0.039489
# SEC_INSTAL_AMT                                      0.001265
# NEW_ACCTS_IN_LAST_SIX_MONTHS                        0.039939
# DELINQUENT_ACCTS_IN_LAST_SIX_MONTHS                 0.301760
# NO_OF_INQUIRIES                                     0.034062
# LOAN_DEFAULT                                        0.032089
# LOANEE_DOB_DAYS                                     0.064250
# DISBURSAL_DATE_DAYS                                 0.000002
# AVERAGE_ACCT_AGE_DAYS                               0.188879
# CREDIT_HISTORY_LENGTH_DAYS                          0.208049
# LTA                                                 0.016845
# EMPLOYMENT_TYPE_Self employed                       0.007369
# PERFORM_CNS_DESC_Low                               -0.034395
# PERFORM_CNS_DESC_Medium                             1.000000
# PERFORM_CNS_DESC_High                              -0.073828
# PERFORM_CNS_DESC_Very high                         -0.085803
#
#                                      PERFORM_CNS_DESC_High  \
# DISBURSED_AMOUNT                                  0.022141
# ASSET_COST                                       -0.009521
# DRIVING_FLAG                                      0.006258
# PRI_NO_OF_ACCTS                                   0.401887
# PRI_ACTIVE_ACCTS                                  0.447246
# PRI_OVERDUE_ACCTS                                 0.078890
# PRI_CURRENT_BALANCE                               0.174777
# PRI_SANCTIONED_AMOUNT                             0.196294
# PRI_DISBURSED_AMOUNT                              0.197062
# SEC_NO_OF_ACCTS                                   0.026547
# SEC_ACTIVE_ACCTS                                  0.024775
# SEC_OVERDUE_ACCTS                                 0.016692
# SEC_CURRENT_BALANCE                               0.014125
# SEC_SANCTIONED_AMOUNT                             0.013703
# SEC_DISBURSED_AMOUNT                              0.013637
# PRIMARY_INSTAL_AMT                                0.060716
# SEC_INSTAL_AMT                                    0.005121
# NEW_ACCTS_IN_LAST_SIX_MONTHS                      0.300228
# DELINQUENT_ACCTS_IN_LAST_SIX_MONTHS               0.212587
# NO_OF_INQUIRIES                                   0.094267
# LOAN_DEFAULT                                      0.003480
# LOANEE_DOB_DAYS                                   0.072662
# DISBURSAL_DATE_DAYS                              -0.002678
# AVERAGE_ACCT_AGE_DAYS                             0.289124
# CREDIT_HISTORY_LENGTH_DAYS                        0.296097
# LTA                                               0.046765
# EMPLOYMENT_TYPE_Self employed                    -0.019387
# PERFORM_CNS_DESC_Low                             -0.080666
# PERFORM_CNS_DESC_Medium                          -0.073828
# PERFORM_CNS_DESC_High                             1.000000
# PERFORM_CNS_DESC_Very high                       -0.201232
#
#                                      PERFORM_CNS_DESC_Very high
# DISBURSED_AMOUNT                                      -0.014467
# ASSET_COST                                            -0.041684
# DRIVING_FLAG                                          -0.000731
# PRI_NO_OF_ACCTS                                        0.326378
# PRI_ACTIVE_ACCTS                                       0.238321
# PRI_OVERDUE_ACCTS                                     -0.120376
# PRI_CURRENT_BALANCE                                    0.082190
# PRI_SANCTIONED_AMOUNT                                  0.102895
# PRI_DISBURSED_AMOUNT                                   0.100019
# SEC_NO_OF_ACCTS                                        0.029763
# SEC_ACTIVE_ACCTS                                       0.025913
# SEC_OVERDUE_ACCTS                                      0.016039
# SEC_CURRENT_BALANCE                                    0.009013
# SEC_SANCTIONED_AMOUNT                                  0.013162
# SEC_DISBURSED_AMOUNT                                   0.012893
# PRIMARY_INSTAL_AMT                                     0.019276
# SEC_INSTAL_AMT                                         0.010416
# NEW_ACCTS_IN_LAST_SIX_MONTHS                           0.166680
# DELINQUENT_ACCTS_IN_LAST_SIX_MONTHS                   -0.060324
# NO_OF_INQUIRIES                                        0.069481
# LOAN_DEFAULT                                          -0.072164
# LOANEE_DOB_DAYS                                        0.082870
# DISBURSAL_DATE_DAYS                                    0.001374
# AVERAGE_ACCT_AGE_DAYS                                  0.216440
# CREDIT_HISTORY_LENGTH_DAYS                             0.208161
# LTA                                                    0.038176
# EMPLOYMENT_TYPE_Self employed                         -0.052068
# PERFORM_CNS_DESC_Low                                  -0.093751
# PERFORM_CNS_DESC_Medium                               -0.085803
# PERFORM_CNS_DESC_High                                 -0.201232
# PERFORM_CNS_DESC_Very high                             1.000000
#
# [31 rows x 31 columns]

# %%
# correlation heatmap
sns.heatmap(df.corr(), cmap="BuPu", robust=True)
# Out:
# <AxesSubplot:>
